# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202103_Programacion_en_R_para_ciencia_de_datos/blob/main/Clases/Clase4/02_Visualizaciones_ggplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 3: Introducción a GGplot2
#
# **Autor:** Miguel Jorquera Viguera<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Jorge Arévalo Labarca<br>
# **E-mail ayudante:** jorge.arevalol@usach.cl
#
# Ggplot es una librería basada en la gramática de gráficos, creadapor Wilkinson (2015). Básicamente la gramática de gráficos nos dice que un gráfico estadístico corresponde a un mapeo entre la data hacia atributos estéticos (como el color, forma o tamaño) de objetos geométricos (como puntos, líneas o barras).
#
# ## Referencias útiles
#
#  * https://ggplot2.tidyverse.org/reference/index.html
#  * https://r4ds.had.co.nz/data-visualisation.html
#  * https://www.rdocumentation.org/packages/ggplot2/versions/3.3.0
#
#
# ## Cheatsheets
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Cargamos la librería
library(ggplot2) # install.packages("ggplot2")
# Otras librerías que pueden ser de interés: leaflet, iplots, highcharter * ,ggmap, visNetwork**

# %%
## Esta celda no es necesaria en Rstudio, es sólo para modificar el tamaño de los gráficos desplegados en el notebook
# Change plot size to 4 x 3
options(repr.plot.width=9, repr.plot.height=6)

# %% [markdown]
# Para entender el funcionamiento de esta grámatica comencemos con un ejemplo analizando la data mpg:

# %%
# "+" es mas o menos lo mismo en ggplot que %>% de dplyr
data(mpg)
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 21  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 22  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 23  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 28  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 205 toyota       toyota tacoma 4wd  3.4   1999 6   auto(l4)   4   15  19  r
# 206 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 207 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 208 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 209 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 210 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 211 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 212 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 214 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 215 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 217 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 218 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 219 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 220 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 221 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 222 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 223 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 224 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 225 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 226 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 227 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 228 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 229 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 230 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 231 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 232 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 233 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 234 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact
# 15  compact
# 16  midsize
# 17  midsize
# 18  midsize
# 19  suv
# 20  suv
# 21  suv
# 22  suv
# 23  suv
# 24  2seater
# 25  2seater
# 26  2seater
# 27  2seater
# 28  2seater
# 29  suv
# 30  suv
# ⋮   ⋮
# 205 pickup
# 206 pickup
# 207 pickup
# 208 compact
# 209 compact
# 210 compact
# 211 compact
# 212 compact
# 213 compact
# 214 compact
# 215 compact
# 216 compact
# 217 compact
# 218 compact
# 219 compact
# 220 compact
# 221 compact
# 222 subcompact
# 223 subcompact
# 224 subcompact
# 225 subcompact
# 226 subcompact
# 227 subcompact
# 228 midsize
# 229 midsize
# 230 midsize
# 231 midsize
# 232 midsize
# 233 midsize
# 234 midsize

# %%
plot(mpg$displ, mpg$hwy) # R base, así podemos generar un gráfico de dispersión con dos vcetores.
# Out:
# plot without title

# %%
ggplot(mpg) + # Indicamos el origen de los datos que buscamos visualizar
    aes(x = displ, y = hwy) + # capa "estética" : aesthetical mapping (indicamos qué variables queremos visualizar)
    geom_point() # capa geométrica, se indica "cómo" queremos visualizar las variables indicadas en el aesthetical mapping
# Out:
# plot without title

# %%
# tambien podemos generar el gráfico de la siguiente manera (aes( coo parametro mapping))
ggplot(mpg, mapping = aes(x = displ, y = hwy)) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# # I. Color, tamaño, forma y otros atributos estéticos
#
# ## I.1. Color
# El color está dado por la variable categórica class (notar que es lo mismo si incluimos el parámetro color, colour o col. ggplot automáticamente entiende lo que queremos :) )

# %%
## Color por "class" dentro de aes
ggplot(mpg) +
    aes(x = displ, y = hwy, color = class) + 
    geom_point()
# Out:
# plot without title

# %%
#y si queremos color azul?

ggplot(mpg) +
    aes(x = displ, y = hwy) + 
    geom_point(color = "blue")
# Out:
# plot without title

# %%
# que sucede si el color no es una variable categórica.

ggplot(mpg) +
    aes(x = displ, y = hwy, color = cyl) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ## I.2. Forma

# %%
## Forma (shape) según "drv"
ggplot(mpg) +
    aes(x = displ, y = hwy, shape = drv) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ## I.3. Forma y color

# %%
## Forma y color (color = class, shape = drv)
ggplot(mpg) +
    aes(x = displ, y = hwy, shape = drv , color = cyl) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ## I.4. Tamaño

# %%
## Tamaño (size) según "cyl"
ggplot(mpg) +
    aes(x = displ, y = hwy, size = cyl) + 
    geom_point()
# Out:
# plot without title

# %%
# size = drv? nota: no tiene sentido dar el tamaño segú nuna variable categórica (R internamente la ordena alfabéticamente y luego asigna el valor del tamañao)
ggplot(mpg) +
    aes(x = displ, y = hwy, size = drv) + 
    geom_point()
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# # II. Facetas
#
# En inglés Facetting, es una manera de dividir la data disponible según variables categóricas y mostrar el mismo gráfico por cada categoría en una misma imagen.

# %%
# Apertura por drv
ggplot(mpg) +
  aes(x = displ,y = hwy) +
  geom_point() +
  facet_wrap(~ drv)
# Out:
# plot without title

# %% [markdown]
# Grafique otras relaciones entre la eficiencia (hwy o cty), tamaño del motor (displ) por cada  número de cilindros (cyl). ¿Qué se observa?

# %%
# Por ejemplo, x=displ,y=hwy , aperturado por número de cilindros
ggplot(mpg) +
  aes(x = displ,y = hwy) +
  geom_point()

# %% [markdown]
# # III. Capas geométricas: prefijo geom_
#
# Hasta aquí hemos utilizado sólo una de las diversas maneras de mostrar (geométricamente hablando) la relación entre las variables hasta aquí descritas.
# En ggplot existe una gran variedad de funciones "geom_", sólo veremos algunas de ellas, aunque en la documentación oficial se describen todas las opciones disponibles https://ggplot2.tidyverse.org/index.html
#
# ## III.1 geom_point()
#
# La fución geom_point() se encarga de visualizar las variables definidas en aes() como un gráfico de dispersión.
#
# ## III.2 geom_smooth()
# Con esta función podemos añadir una curva de tendencia a nuestros datos

# %%
#geom_smooth()

ggplot(mpg) +
  aes(x = displ,y = hwy) +
  geom_point() +
  geom_smooth(method = "auto")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
?geom_smooth

# %% [markdown]
# ¿Cómo podemos graficar las curvas de tendencia para cada tipo de tracción (drv)?

# %%
# por color
ggplot(mpg) +
  aes(x = displ,y = hwy, color = drv) +
  geom_point() +
  geom_smooth(method = "auto")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# y usando facet_wrap
ggplot(mpg) +
  aes(x = displ,y = hwy) +
  geom_point() +
  geom_smooth(method = "auto") +
  facet_wrap(~ drv)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ## III.3 geom_boxplot() y geom_jitter()
#  Podemos variar la forma del gráfico modificando la capa geométrica con las funciones geom_
#  Por ejemplo, hace un rato visualizamos la relación entre hwy y drv. Para este tipo de relaciones es más informativo un gráfico de cajas.

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(mpg, aes(x =  drv ,y = hwy )) +
  geom_point()
# Out:
# plot without title

# %%
# usar capa geom_jitter(). Añade un grado de dispersión entre ellos los puntos de un gráfico de dispersión para una mejor visualización.
ggplot(mpg) +
  aes(x =  drv ,y = hwy) +
  geom_point() + 
  geom_jitter()
# Out:
# plot without title

# %%
## usar capa geom_boxplot()
ggplot(mpg) +
  aes(x = drv ,y = hwy) +
  geom_boxplot()
# Out:
# plot without title

# %%
# usar capa geom_violin(). Proporciona una estimaciónd de la deensidad de los valores graficados

ggplot(mpg) +
  aes(x =  drv ,y = hwy) + 
  geom_violin()
# Out:
# plot without title

# %% [markdown]
# ## III.4 geom_histogram() y  geom_freqpoly()
#
# Con estas funciones es posible graficar histogramas y la frecuencia absoluta a través de una curva poligonal

# %%
hist(mpg$hwy)
# Out:
# Plot with title “Histogram of mpg$hwy”

# %%
## histograma . Parámetro bins =30 en geom_histogram()

ggplot(mpg) +
  aes(x = hwy) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Con base
hist(mpg$hwy, breaks = 30)
# Out:
# Plot with title “Histogram of mpg$hwy”

# %%
# podemos aperturar por drv (en color  y fill)
ggplot(mpg) +
  aes(x = hwy, color = drv) +
  geom_histogram() 


#usando facet_wrap

ggplot(mpg) +
  aes(x = hwy) +
  geom_histogram() +
  facet_wrap(~ drv)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
## polígono de frecuencias # geom_freqpoly
ggplot(mpg) +
  aes(x = hwy, color = drv) +
  geom_freqpoly()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## III.4 geom_line()
#
# Podemos generar gráficos de linea, por ejemplo de series temporales.

# %%
install.packages("httr")
install.packages("jsonlite")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(dplyr)
library(httr)
library(jsonlite)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
url_base <-"https://mindicador.cl"

consulta <- GET(url_base,path = "/api/dolar/2020")
consulta

text <- content(consulta, as = "text")
content <- fromJSON(text)
content$serie
# Out:
# Response [https://mindicador.cl/api/dolar/2020]
#   Date: 2021-04-30 01:43
#   Status: 200
#   Content-Type: application/json; charset=utf-8
#   Size: 13.2 kB
#     fecha                    valor
# 1   2020-12-30T03:00:00.000Z 711.24
# 2   2020-12-29T03:00:00.000Z 710.64
# 3   2020-12-28T03:00:00.000Z 710.26
# 4   2020-12-24T03:00:00.000Z 716.25
# 5   2020-12-23T03:00:00.000Z 728.96
# 6   2020-12-22T03:00:00.000Z 730.70
# 7   2020-12-21T03:00:00.000Z 723.85
# 8   2020-12-18T03:00:00.000Z 723.44
# 9   2020-12-17T03:00:00.000Z 735.09
# 10  2020-12-16T03:00:00.000Z 734.23
# 11  2020-12-15T03:00:00.000Z 731.58
# 12  2020-12-14T03:00:00.000Z 733.55
# 13  2020-12-11T03:00:00.000Z 738.17
# 14  2020-12-10T03:00:00.000Z 739.45
# 15  2020-12-09T03:00:00.000Z 744.82
# 16  2020-12-07T03:00:00.000Z 747.61
# 17  2020-12-04T03:00:00.000Z 752.03
# 18  2020-12-03T03:00:00.000Z 755.34
# 19  2020-12-02T03:00:00.000Z 760.16
# 20  2020-12-01T03:00:00.000Z 767.29
# 21  2020-11-30T03:00:00.000Z 766.69
# 22  2020-11-27T03:00:00.000Z 766.00
# 23  2020-11-26T03:00:00.000Z 771.68
# 24  2020-11-25T03:00:00.000Z 772.83
# 25  2020-11-24T03:00:00.000Z 765.96
# 26  2020-11-23T03:00:00.000Z 761.55
# 27  2020-11-20T03:00:00.000Z 758.62
# 28  2020-11-19T03:00:00.000Z 758.10
# 29  2020-11-18T03:00:00.000Z 767.05
# 30  2020-11-17T03:00:00.000Z 767.86
# ⋮   ⋮                        ⋮
# 222 2020-02-12T03:00:00.000Z 792.48
# 223 2020-02-11T03:00:00.000Z 795.88
# 224 2020-02-10T03:00:00.000Z 788.80
# 225 2020-02-07T03:00:00.000Z 779.12
# 226 2020-02-06T03:00:00.000Z 776.99
# 227 2020-02-05T03:00:00.000Z 781.78
# 228 2020-02-04T03:00:00.000Z 790.92
# 229 2020-02-03T03:00:00.000Z 799.11
# 230 2020-01-31T03:00:00.000Z 797.96
# 231 2020-01-30T03:00:00.000Z 788.18
# 232 2020-01-29T03:00:00.000Z 788.13
# 233 2020-01-28T03:00:00.000Z 787.86
# 234 2020-01-27T03:00:00.000Z 776.52
# 235 2020-01-24T03:00:00.000Z 771.94
# 236 2020-01-23T03:00:00.000Z 772.12
# 237 2020-01-22T03:00:00.000Z 770.50
# 238 2020-01-21T03:00:00.000Z 769.93
# 239 2020-01-20T03:00:00.000Z 771.38
# 240 2020-01-17T03:00:00.000Z 773.36
# 241 2020-01-16T03:00:00.000Z 772.01
# 242 2020-01-15T03:00:00.000Z 772.29
# 243 2020-01-14T03:00:00.000Z 777.66
# 244 2020-01-13T03:00:00.000Z 770.56
# 245 2020-01-10T03:00:00.000Z 764.69
# 246 2020-01-09T03:00:00.000Z 766.83
# 247 2020-01-08T03:00:00.000Z 773.12
# 248 2020-01-07T03:00:00.000Z 771.82
# 249 2020-01-06T03:00:00.000Z 758.49
# 250 2020-01-03T03:00:00.000Z 754.16
# 251 2020-01-02T03:00:00.000Z 748.74

# %% [markdown]
# # IV. Otros parámetros visuales
# ## IV.1 Etiquetas
# Con la capa llamada `labs()`, podemos modificar los nombres de los ejes, títulos, subtítulos y leyenda.
# ## IV.2 Ejes y escala
# Existen diversas funciones que nos peritirán modificar parámetros visuales de los ejes, en función del tipo de dato que estos representen. Algunos de los más usuales son los siguientes
#  * `scale_x_date()`, `scale_y_date()`
#  * `scale_x_continuous()`, `scale_y_continuous()`
#  * `scale_x_discrete()`, `scale_y_discrete()`
#  * `scale_x_log10()`, `scale_y_log10()`
#
# En la documentación pueden buscar las demmás opcione mediante el prefijo _scale_

# %%
##
dolar <- content$serie

# %%
head(dolar)
# Out:
#   fecha                    valor
# 1 2020-12-30T03:00:00.000Z 711.24
# 2 2020-12-29T03:00:00.000Z 710.64
# 3 2020-12-28T03:00:00.000Z 710.26
# 4 2020-12-24T03:00:00.000Z 716.25
# 5 2020-12-23T03:00:00.000Z 728.96
# 6 2020-12-22T03:00:00.000Z 730.70

# %%
dolar <- dolar %>%
  mutate(fecha = as.Date(fecha))

# %%
head(dolar)
# Out:
#   fecha      valor
# 1 2021-04-30 705.09
# 2 2021-04-29 700.15
# 3 2021-04-28 702.02
# 4 2021-04-27 707.05
# 5 2021-04-26 712.54
# 6 2021-04-23 705.41

# %%
dolar %>%
  ggplot() +
  aes(x = fecha, y = valor) +
  geom_line()
# Out:
# plot without title

# %%
## Ejemplo, consideramos incluir etiquetas y cortes en el eje de tiempo
dolar %>%
  ggplot() +
  aes(x = fecha, y = valor) +
  geom_line() +
  scale_x_date( date_breaks = "month") +
  scale_y_continuous(n.breaks = 10) +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
