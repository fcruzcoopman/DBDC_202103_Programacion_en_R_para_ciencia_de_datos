# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202103_Programacion_en_R_para_ciencia_de_datos/blob/main/Clases/Clase6/Clase6_1_Estadisticos_descriptivos_y_correlaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
options(repr.plot.width=8, repr.plot.height=6)

# %% [markdown]
# # Parte 4: Análisis descriptivo con R
#
# **Autor:** Miguel Jorquera Viguera<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Jorge Arévalo Labarca<br>
# **E-mail ayudante:** jorge.arevalol@usach.cl
#
#
# Una de las fases principales dentro de un proyecto de Data Science, corresponde al análisis exploratorio de datos. Es en esta etapa donde se realizan los primeros hallazgos, se verifica la calidad de los datos, se detectan anomalías, se identifican patrones y se realizan preguntas claves que permitan comenzar a realizar inferencias , o si es el caso, comenzar a plantear modelos con fines predictivos.
#
# ## I. Estadísticos descriptivos
# ### a) Medidas de posición
# Corresponden a valores que nos permiten dividir nuestra muestra en conjuntos con aproximadamente la misma cantidad de individuos.
# ### b) Medidas de tendencia central
# Corresponden a medidas a las que tienden “agruparse” los datos de la muestra .
# ### c) Medidas de dispersión
# Medidas que cuantifican el nivel de heterogeneidad de una variable numérica.
#
#
# En R contamos con funciones para lo anterior:
#
#  - summary(): Por defecto entrega estadísticos de posición (cuartiles), min, max y media.
#  - quantiles(): Retorna uno o varios percentiles de interés.
#  - mean(): Calcula la media de un vector numérico.
#  - median(): Calcula la mediana de un vector numérico.
#  - sd(): Retorna la desviación estándar muestral.
#  - var(): Retorna la varianza muestral.
#
# ### I.1. Descripción de data _mpg_
#
# Analicemos el rendimiento en ciudad en función de los estadísticos descriptivos más conocidos.

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
data(mpg)
head(mpg)
# cyl: cilindros
# displ: Engine displacement, in lt "cilindrada"
# drv: traccion
# cty: city miles miles per gallonb
# hwy: highway miles per gallon
# fl: fuel type
# class: "type" of car
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %% [markdown]
# ### Media, Mediana  y percentiles
# Los percentiles, en particular la mediana corresponden a estadísticos de posición, ya que nos permiten "ubicarnos" dentro de la muestra que estamos analizando y nos dan una primera idea sobre la distribución de los datos a analizar. Por su parte la media (aritmética) corresponde a un estadístico de tendencia central.

# %%
# describamos el rendimiento en carretera en función de los estadísticos de pos., tendencia central  y dispersión

# promedio (media aritmética): Medida de tendencia central
print(paste("El promedio es: ", mean(mpg$hwy)))

# mediana: Es una medida de posición
# Corresponde al valor que acumula al 50% de la información
print(paste("La mediana es: ", median(mpg$hwy)))
# El 50% de los automóviles de la muestra, tienen un rendimiento (en carretera) menor o igual 24 mpg.


# percentiles: También corresponden a medidas de posición 
#quantile()# Recibe un vector con los elementos sobre los que queremos calcular un percentil y recibe el percentil a calcular.

quantile(mpg$hwy, 0.5 )# Percentil 50%, se ingresa como parámetro 0.5 (siempre es un valor entre 0 y 1)

# Percentil 25 y 50
quantile(mpg$hwy, c(0.25,0.5) ) # Podemos consultar por un vector de percentiles
# El 25% de los autos, tiene un rendimiento menor o igual a 18mpg.
# Out:
# [1] "El promedio es:  23.4401709401709"
# [1] "La mediana es:  24"
# 50%
#  24
# 25% 50%
#  18  24

# %%
# recordar que podemos visualizar los cuartiles en un boxplot

mpg %>%
  ggplot() +
  aes(y = hwy) +
  geom_boxplot() 

quantile(mpg$hwy, c(0.25,0.5,0.75) )
# Out:
# 25% 50% 75%
#  18  24  27
# plot without title

# %% [markdown]
# ### Medidas de dispersión
# Rango, desviación estándar  y rango intercuartílico. Son medidas que buscan cuantificar el nivel de dispersión o heterogeneidad de nuestra muestra.

# %%
# medidas de dispersión ---------------

# Rango: Diferencia entre el mayor y menor valor de la muestra
max(mpg$hwy) - min(mpg$hwy) # En nuestra muestra, la diferencia de rendimiento entre dos autos nunca será mayor a 32mpg. 


# Cómo saber cuál es el auto que tiene el menor rendimiento en carretera
# Desviación estándar
sd(mpg$hwy) # En promedio los rendimientos se "desvían" en 6mpg de la media (23mpg)
sqrt(sum((mpg$hwy-mean(mpg$hwy))^2)/(length(mpg$hwy)-1) )





# Coef de variación = desviación estandar / |promedio|
# Out:
# [1] 32
# [1] 5.954643
# [1] 5.954643

# %%
unique(mpg$class)
# Out:
# [1] "compact"    "midsize"    "suv"        "2seater"    "minivan"
# [6] "pickup"     "subcompact"

# %%
mpg %>% 
  filter(class %in% c("minivan","2seater")) %>%
  filter(hwy >= 20) %>%
  ggplot() +
  aes(x = class, y = hwy) +
  geom_boxplot()
# Out:
# plot without title

# %%
mpg %>% 
  filter(class %in% c("minivan","2seater")) %>%
  filter(hwy >= 20) %>%
  group_by(class) %>%
  summarise(desv_est_hwy = sd(hwy),
            cv_hwy = sd(hwy)/abs(mean(hwy)) )

  # Son comparables los niveles de dispersión de ambas muestras?
# Out:
#   class   desv_est_hwy cv_hwy
# 1 2seater 1.303840     0.05257421
# 2 minivan 1.100505     0.04805698

# %%
# Ejemplo más extremo:
# Grupo1: con salario promedio de 300.000, sd = 500.000
# Grupo2: con salario promedio de 1.000.000 , sd = 500.000

# Coeficiente de variación sd/|media|
#G1
500000/300000

#G2
500000/1000000
# Out:
# [1] 1.666667
# [1] 0.5

# %%
# Rango Inter-cuartílico
# Una obs se considera "extrema" si si valor está por sobre (debajo) 1.5 veces el rango intercuartílico (RI = Q3- Q1)
 IQR(mpg$hwy)
 quantile(mpg$hwy, 0.75) - quantile(mpg$hwy, 0.25)
# Out:
# [1] 9
# 75%
#   9

# %%
# Ejemplo: hwy en clase SUV
mpg %>% 
  filter(class == "suv") %>%
  ggplot() +
  aes(x = class, y = hwy) +
  #geom_jitter() + 
  geom_boxplot()
# Out:
# plot without title

# %%
# Outliers según criterio del rango inter-cuartílico

unique(mpg$class)
# Out:
# [1] "compact"    "midsize"    "suv"        "2seater"    "minivan"
# [6] "pickup"     "subcompact"

# %%
# lim inf 1.5*IQR (por "debajo")
mpg %>%
  filter(class == "suv") %>%
  filter(hwy < quantile(hwy,0.25) - 1.5*IQR(hwy)  )

# lim sup 1.5*IQR (por "arriba")
mpg %>%
  filter(class == "suv") %>%
  filter(hwy > quantile(hwy,0.75) + 1.5*IQR(hwy)  )
# Out:
#   manufacturer model        displ year cyl trans      drv cty hwy fl class
# 1 subaru       forester awd 2.5   1999 4   manual(m5) 4   18  25  r  suv
# 2 subaru       forester awd 2.5   1999 4   auto(l4)   4   18  24  r  suv
# 3 subaru       forester awd 2.5   2008 4   manual(m5) 4   20  27  r  suv
# 4 subaru       forester awd 2.5   2008 4   manual(m5) 4   19  25  p  suv
# 5 subaru       forester awd 2.5   2008 4   auto(l4)   4   20  26  r  suv
# 6 subaru       forester awd 2.5   2008 4   auto(l4)   4   18  23  p  suv
#   manufacturer model              displ year cyl trans    drv cty hwy fl class
# 1 dodge        durango 4wd        4.7   2008 8   auto(l5) 4   9   12  e  suv
# 2 jeep         grand cherokee 4wd 4.7   2008 8   auto(l5) 4   9   12  e  suv

# %% [markdown]
# ## II. Correlación de variables

# %% [markdown]
# Las medidas de correlación buscan cuantificar el nivel de asociación que existe entre dos variables. Uno de los coeficientes más populares para medir la **dependencia lineal** entre dos variables corresponde al coeficiente de correlación de Pearson.
#
# Matemáticamente, el coeficiente de correlación de Pearson entre dos variables aleatorias X e Y se define como
#
# $$\rho = \dfrac{\mathbb{E}[(X-\mu_X)(Y-\mu_Y)]}{\sqrt{\sigma^2_X\sigma^2_Y}}$$
#
# Este coeficiente varía entre -1 y 1, y alcanza dichos valores siempre que X e Y formen una recta.
#
# Exploremos algunos ejemplos

# %% [markdown]
# **¿Cómo es la relación entre el rendimiento en carretera y el tamaño del motor?**

# %%
# Gráficamente x = displ, y = hwy
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point()
# Out:
# plot without title

# %%
# podemos añadir "recta" de tendencia
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
cor(mpg$hwy, mpg$displ)
# Out:
# [1] -0.76602

# %% [markdown]
# Podemos seleccionar las columnas *mpg,disp,hp,drat,wt,qsec* y generar un gráfico de dispersión para cada par de ellas, con la función plot() del paquete _base_.

# %%
data(mtcars)
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
#Podemos graficar algunas de las variables de interés

aux <- mtcars %>% 
    select(mpg,disp,hp,drat,wt,qsec)
head(aux)
# Out:
#                   mpg  disp hp  drat wt    qsec
# Mazda RX4         21.0 160  110 3.90 2.620 16.46
# Mazda RX4 Wag     21.0 160  110 3.90 2.875 17.02
# Datsun 710        22.8 108   93 3.85 2.320 18.61
# Hornet 4 Drive    21.4 258  110 3.08 3.215 19.44
# Hornet Sportabout 18.7 360  175 3.15 3.440 17.02
# Valiant           18.1 225  105 2.76 3.460 20.22

# %%
options(repr.plot.width=16, repr.plot.height=9)
plot(aux)
# Out:
# plot without title

# %% [markdown]
# ### P1. Comando cor
# Investigue el comando cor y utilícelo con la selección previa de columnas.
# ¿Qué observa?

# %% [markdown]
# ### P2. De acuerdo a  la documentación, cambie el método de cálculo a "spearman"
# ¿Que observa?

# %%
cor(aux) # por defecto calcula correlación de pearson
# Out:
#      mpg        disp       hp         drat        wt         qsec
# mpg   1.0000000 -0.8475514 -0.7761684  0.68117191 -0.8676594  0.41868403
# disp -0.8475514  1.0000000  0.7909486 -0.71021393  0.8879799 -0.43369788
# hp   -0.7761684  0.7909486  1.0000000 -0.44875912  0.6587479 -0.70822339
# drat  0.6811719 -0.7102139 -0.4487591  1.00000000 -0.7124406  0.09120476
# wt   -0.8676594  0.8879799  0.6587479 -0.71244065  1.0000000 -0.17471588
# qsec  0.4186840 -0.4336979 -0.7082234  0.09120476 -0.1747159  1.00000000

# %% [markdown]
# ## NOTA: parámetro method de la función cor()

# %%
set.seed(123) # Semilla para generar númeos aleatorios
x <- rnorm(100) # variable X
e <- rnorm(100, sd = .5) # error aleatorio
# Modelar y como funcion de x y un error aleatorio
# y = f(x) + e
y <- 1+ 3*x^3 + e

A <- data.frame(x = x, y = y)

# %% [markdown]
# $y = f(x) + \epsilon$ \\
# $y = 3x^{3} + 1 + \epsilon$

# %%
# Gráficamente la relación de x e  y 
  
A %>%
    ggplot() +
    aes(x = x, y = y) +
    geom_point()
# Out:
# plot without title

# %%
# parámetro method de la función cor()
cor(A$x,A$y, method = "pearson")
cor(A$x,A$y, method = "spearman")
# Out:
# [1] 0.8257649
# [1] 0.9065107

# %% [markdown]
# ## Gráfico de correlación

# %%
#install.packages("corrplot")
library(corrplot)

# función corrplot()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# corrplot 0.88 loaded

# %% [markdown]
# ### P3. Opciones de corrplot
# Identifique (en la documentación de la función corplot) otros métodos de visualización

# %%
matriz_cor <- cor(aux)
matriz_cor
# Out:
#      mpg        disp       hp         drat        wt         qsec
# mpg   1.0000000 -0.8475514 -0.7761684  0.68117191 -0.8676594  0.41868403
# disp -0.8475514  1.0000000  0.7909486 -0.71021393  0.8879799 -0.43369788
# hp   -0.7761684  0.7909486  1.0000000 -0.44875912  0.6587479 -0.70822339
# drat  0.6811719 -0.7102139 -0.4487591  1.00000000 -0.7124406  0.09120476
# wt   -0.8676594  0.8879799  0.6587479 -0.71244065  1.0000000 -0.17471588
# qsec  0.4186840 -0.4336979 -0.7082234  0.09120476 -0.1747159  1.00000000

# %%
# Función corplot()
# podemos modificar el parámetro "method"
corrplot(matriz_cor, method = "ellipse")
# Out:
# Plot with title “”

# %%
?corrplot
